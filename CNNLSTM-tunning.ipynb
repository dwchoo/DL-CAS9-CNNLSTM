# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format ='retina'

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    gpu_num = 1
    try:
        tf.config.experimental.set_visible_devices(gpus[gpu_num], 'GPU')
        #tf.config.experimental.set_memory_growth(gpus[gpu_num], True)
        tf.config.experimental.set_virtual_device_configuration(
            gpus[gpu_num],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4000)])
    except RuntimeError as e:
        print(e)

# %%
default_HP = {
    'CNN_1_kernal' : 16,
    'CNN_1_RNN' : 64,
    'CNN_2_kernal' : 32,
    'CNN_2_RNN' : 128,
    'CNN_3_kernal' : 64,
    'CNN_3_RNN' : 256,
    'CNN_4_kernal' : 128,
    'CNN_4_RNN' : 256,
    'CNN_5_kernal' : 128,
    'CNN_5_RNN' : 256,

    'DNN_1' : 100,
    'DNN_2' : 100,
    'DNN_rate' : 100,

    'CNN_dropout' : 0.5,
    'DNN_dropout' : 0.5,

    'learning_rate' : 0.0001
}

# %%
from Model import *

# %%
CNNLSTM_SpCas9_model = CNNLSTM_SpCas9(HP=default_HP, random_seed=1234)

# %%
CNNLSTM_SpCas9_model.CNNLSTM_MTL_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 30, 4)]      0
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 30, 128)      640         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 30, 128)      1152        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 30, 128)      1664        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 30, 128)      2176        input_1[0][0]
# ...

# %%
CNNLSTM_SpCas9_model.model_train()
# Out:
# Train on 11548 samples, validate on 1284 samples
# Epoch 1/200
# 11548/11548 [==============================] - 15s 1ms/sample - loss: 6.0570 - class_1_loss: 2.3590 - class_2_loss: 2.3575 - class_final_loss: 2.3898 - rate_loss: 0.1454 - class_1_accuracy: 0.1182 - class_2_accuracy: 0.1216 - class_final_accuracy: 0.1137 - val_loss: 5.8695 - val_class_1_loss: 2.2782 - val_class_2_loss: 2.2909 - val_class_final_loss: 2.3768 - val_rate_loss: 0.1226 - val_class_1_accuracy: 0.1355 - val_class_2_accuracy: 0.1340 - val_class_final_accuracy: 0.1192
# Epoch 2/200
# ...

# %%
CNNLSTM_SpCas9_model.model_evaluate(1)
# Out:
# (0.7130656689159826, 2.5229186083729905e-85)

# %%
test_prediction = CNNLSTM_SpCas9_model.CNNLSTM_regression_model.predict(CNNLSTM_SpCas9_model.X_test)
test_prediction = test_prediction.reshape(-1,)
test_true = CNNLSTM_SpCas9_model.rate_test.reshape(-1,)

# %%
# Out:
# (542,)

# %%
fig = CNNLSTM_SpCas9_model.plot_scatter(test_prediction,test_true,'Test data')

# %%
image = CNNLSTM_SpCas9_model.log_plot(epoch=1,
                                      model=CNNLSTM_SpCas9_model.CNNLSTM_regression_model,
                                     input_data=CNNLSTM_SpCas9_model.X_test,
                                     true_data=CNNLSTM_SpCas9_model.rate_test,
                                     plot=CNNLSTM_SpCas9_model.plot_scatter,
                                     )
