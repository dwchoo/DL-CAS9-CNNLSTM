# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format ='retina'
# %load_ext tensorboard

# %%
# %load skopt_module.py
import numpy as np
import skopt
from skopt import gp_minimize
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_convergence, plot_objective, plot_evaluations
from skopt.utils import use_named_args

from mnist import mnist

hp_dict = {
    'cnn1' : 500,
    'cnn2' : 500,
    'dropout' : 0.3,
    'learning_rate' : 0.0005
    }

default_HP = list(hp_dict.values())

def mnist_model_tunning(hp_list):
    HP_list2dict = {
    'cnn1' : int(hp_list[0]),
    'cnn2' : int(hp_list[1]),
    'dropout' : float(hp_list[2]),
    'learning_rate' : float(hp_list[3])
    }
    print("======================start trainning=======================")
    print(HP_list2dict.items())
    mnist_model = mnist(hp_dict=HP_list2dict)
    mnist_model.model()
    mnist_model.training()
    mnist_model.evaluate()
    loss = mnist_model.loss
    return loss

dim_CNN_1_nodes = Integer(low=10, high=500, name='CNN_1_node')
dim_CNN_2_nodes = Integer(low=10, high=500, name='CNN_2_node')
dim_dropout_nodes = Real(low=0.001, high=0.5, name='Dropout_node')
dim_learning_rate_nodes = Real(low=1e-6, high=1e-1, prior='log-uniform',name='Learning_rate_node')

dimension_HP = [
                dim_CNN_1_nodes  ,
                dim_CNN_2_nodes  ,
                dim_dropout_nodes ,
                dim_learning_rate_nodes
                ]



n_cell = 20
n_random_starts = 10

gp_fitting = gp_minimize(func=mnist_model_tunning,
                        dimensions=dimension_HP,
                        n_calls=n_cell,
                        n_random_starts=n_random_starts,
                        acq_func='EI',
                        x0=default_HP
                        )
# Out:
# ======================start trainning=======================
# dict_items([('cnn1', 500), ('cnn2', 500), ('dropout', 0.3), ('learning_rate', 0.0005)])
# Train on 60000 samples
# Epoch 1/5
#    32/60000 [..............................] - ETA: 1:06:26 - loss: 2.3192 - accuracy: 0.0938WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.176541). Check your callbacks.
# 60000/60000 [==============================] - 19s 319us/sample - loss: 0.1225 - accuracy: 0.9617
# Epoch 2/5
# 60000/60000 [==============================] - 17s 278us/sample - loss: 0.0451 - accuracy: 0.9858
# Epoch 3/5
# 60000/60000 [==============================] - 17s 285us/sample - loss: 0.0342 - accuracy: 0.9887
# Epoch 4/5
# 60000/60000 [==============================] - 17s 284us/sample - loss: 0.0253 - accuracy: 0.9918
# Epoch 5/5
# 60000/60000 [==============================] - 17s 283us/sample - loss: 0.0219 - accuracy: 0.9926
# 10000/10000 - 1s - loss: 0.0269 - accuracy: 0.9917
# ======================start trainning=======================
# dict_items([('cnn1', 104), ('cnn2', 148), ('dropout', 0.2491015776469141), ('learning_rate', 0.0005057498882979864)])
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 13s 216us/sample - loss: 0.1847 - accuracy: 0.9442
# Epoch 2/5
# 60000/60000 [==============================] - 13s 211us/sample - loss: 0.0631 - accuracy: 0.9807
# Epoch 3/5
# 60000/60000 [==============================] - 13s 211us/sample - loss: 0.0476 - accuracy: 0.9853
# Epoch 4/5
# 60000/60000 [==============================] - 13s 210us/sample - loss: 0.0366 - accuracy: 0.9890
# Epoch 5/5
# 60000/60000 [==============================] - 13s 209us/sample - loss: 0.0318 - accuracy: 0.9896
# 10000/10000 - 1s - loss: 0.0297 - accuracy: 0.9892
# ======================start trainning=======================
# dict_items([('cnn1', 423), ('cnn2', 355), ('dropout', 0.13429747440744882), ('learning_rate', 6.693436442383847e-05)])
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 16s 264us/sample - loss: 0.3002 - accuracy: 0.9186
# Epoch 2/5
# 60000/60000 [==============================] - 15s 255us/sample - loss: 0.0912 - accuracy: 0.9736
# Epoch 3/5
# 60000/60000 [==============================] - 15s 256us/sample - loss: 0.0670 - accuracy: 0.9799
# Epoch 4/5
# 60000/60000 [==============================] - 15s 255us/sample - loss: 0.0553 - accuracy: 0.9832
# Epoch 5/5
# 60000/60000 [==============================] - 15s 257us/sample - loss: 0.0463 - accuracy: 0.9859
# 10000/10000 - 1s - loss: 0.0389 - accuracy: 0.9869
# ======================start trainning=======================
# dict_items([('cnn1', 310), ('cnn2', 210), ('dropout', 0.058611896904896446), ('learning_rate', 1.1079356192476118e-06)])
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 14s 231us/sample - loss: 2.2318 - accuracy: 0.3718
# Epoch 2/5
# 60000/60000 [==============================] - 14s 226us/sample - loss: 2.0206 - accuracy: 0.6839
# Epoch 3/5
# 60000/60000 [==============================] - 14s 228us/sample - loss: 1.6618 - accuracy: 0.7514
# Epoch 4/5
# 60000/60000 [==============================] - 13s 225us/sample - loss: 1.2523 - accuracy: 0.7860
# Epoch 5/5
# 60000/60000 [==============================] - 14s 229us/sample - loss: 0.9336 - accuracy: 0.8111
# 10000/10000 - 1s - loss: 0.7889 - accuracy: 0.8404
# ======================start trainning=======================
# dict_items([('cnn1', 71), ('cnn2', 239), ('dropout', 0.2273748725511944), ('learning_rate', 0.00812999549821319)])
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 13s 218us/sample - loss: 0.1488 - accuracy: 0.9544
# Epoch 2/5
# 60000/60000 [==============================] - 13s 213us/sample - loss: 0.1030 - accuracy: 0.9702
# Epoch 3/5
# 60000/60000 [==============================] - 13s 212us/sample - loss: 0.0918 - accuracy: 0.9732
# Epoch 4/5
# 60000/60000 [==============================] - 13s 213us/sample - loss: 0.0901 - accuracy: 0.9743
# Epoch 5/5
# 60000/60000 [==============================] - 13s 213us/sample - loss: 0.0962 - accuracy: 0.9737
# 10000/10000 - 1s - loss: 0.0640 - accuracy: 0.9810
# ======================start trainning=======================
# dict_items([('cnn1', 375), ('cnn2', 265), ('dropout', 0.3262383434909301), ('learning_rate', 0.0004097801080729512)])
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 14s 239us/sample - loss: 0.1583 - accuracy: 0.9515
# Epoch 2/5
# 60000/60000 [==============================] - 14s 231us/sample - loss: 0.0538 - accuracy: 0.9834
# Epoch 3/5
# 60000/60000 [==============================] - 14s 232us/sample - loss: 0.0400 - accuracy: 0.9872
# Epoch 4/5
# 60000/60000 [==============================] - 14s 232us/sample - loss: 0.0330 - accuracy: 0.9898
# Epoch 5/5
# 60000/60000 [==============================] - 14s 236us/sample - loss: 0.0267 - accuracy: 0.9915
# 10000/10000 - 1s - loss: 0.0312 - accuracy: 0.9891
# ======================start trainning=======================
# dict_items([('cnn1', 240), ('cnn2', 211), ('dropout', 0.25575916157433326), ('learning_rate', 3.327999623009409e-05)])
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 13s 225us/sample - loss: 0.6380 - accuracy: 0.8314
# Epoch 2/5
# 60000/60000 [==============================] - 13s 218us/sample - loss: 0.1994 - accuracy: 0.9416
# Epoch 3/5
# 60000/60000 [==============================] - 13s 218us/sample - loss: 0.1399 - accuracy: 0.9590
# Epoch 4/5
# 60000/60000 [==============================] - 13s 219us/sample - loss: 0.1120 - accuracy: 0.9667
# Epoch 5/5
# 60000/60000 [==============================] - 13s 220us/sample - loss: 0.0949 - accuracy: 0.9716
# 10000/10000 - 1s - loss: 0.0679 - accuracy: 0.9796
# ======================start trainning=======================
# dict_items([('cnn1', 403), ('cnn2', 137), ('dropout', 0.12018899280787816), ('learning_rate', 0.0002277126178665675)])
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 14s 230us/sample - loss: 0.2037 - accuracy: 0.9396
# Epoch 2/5
# 60000/60000 [==============================] - 14s 226us/sample - loss: 0.0663 - accuracy: 0.9797
# Epoch 3/5
# 60000/60000 [==============================] - 14s 226us/sample - loss: 0.0484 - accuracy: 0.9851
# Epoch 4/5
# 60000/60000 [==============================] - 14s 229us/sample - loss: 0.0379 - accuracy: 0.9883
# Epoch 5/5
# 60000/60000 [==============================] - 14s 227us/sample - loss: 0.0321 - accuracy: 0.9897
# 10000/10000 - 1s - loss: 0.0303 - accuracy: 0.9903
# ======================start trainning=======================
# dict_items([('cnn1', 153), ('cnn2', 133), ('dropout', 0.41953648842483426), ('learning_rate', 1.5761486744388343e-05)])
# Train on 60000 samples
# Epoch 1/5

# %%
plot1 = plot_evaluations(gp_fitting)
plot2 = plot_objective(gp_fitting)

# %%
print(gp_fitting.fun)
print(gp_fitting.x)

# %%
#%run skopt_module.py

# %%
# %debug

# %%
int(0.0001)
